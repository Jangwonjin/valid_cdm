# %%
import pickle
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
with open('cum_mean_0.pickle','rb') as f:
    mean1 = pickle.load(f)
    
with open('cum_mean_1.pickle','rb') as f:
    mean2 = pickle.load(f)

with open('cum_mean_2.pickle','rb') as f:
    mean3 = pickle.load(f)

with open('cum_mean_3.pickle','rb') as f:
    mean4 = pickle.load(f)

with open('cum_mean_4.pickle','rb') as f:
    mean5 = pickle.load(f)

with open('cum_mean_5.pickle','rb') as f:
    mean6 = pickle.load(f)    
    
with open('cum_mean_6.pickle','rb') as f:
    mean7 = pickle.load(f)
    
with open('cum_mean_7.pickle','rb') as f:
    mean8 = pickle.load(f)

# %%
xrange = range(1, 1501)

# %%
cmap = plt.get_cmap('hsv')

# %%
plt.figure(figsize=(12,7))

plt.plot(xrange, mean1, label = 'H0', c = 'black', linestyle = 'dotted')
plt.plot(xrange, mean2, label = 'H1', c = cmap(210))
plt.plot(xrange, mean3, label = 'H2', c = cmap(180))
plt.plot(xrange, mean4, label = 'H3', c = cmap(140))
plt.plot(xrange, mean5, label = 'H4', c = cmap(115))
plt.plot(xrange, mean6, label = 'H5', c = cmap(64))
plt.plot(xrange, mean7, label = 'H6', c = cmap(40))
plt.plot(xrange, mean8, label = 'H7', c = cmap(10))

plt.xlabel('Iteration')
plt.ylabel('Mean of cost')
plt.xscale('log')
plt.legend(loc = 'upper right')
